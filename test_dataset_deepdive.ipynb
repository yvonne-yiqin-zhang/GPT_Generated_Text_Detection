# %%
import pandas as pd
import pickle

# %% [markdown]
# # Load all dataset

# %%
gpt3 = pd.read_pickle('./dataset/text_3000.pickle')
gpt35 = pd.read_pickle('./dataset/text_3000_Turbo.pickle')

# %%
gpt3['prompt'] = gpt3['text'].apply(lambda x: ' '.join(x.split()[:7]))
gpt35['prompt'] = gpt35['text'].apply(lambda x: ' '.join(x.split()[:7]))

# %% [markdown]
# #### Random sample testdata from GPT3 and GPT3.5

# %%
df = pd.DataFrame(columns=['prompt', 'index_gpt3', 'gpt3', 'index_gpt35', 'gpt35'])

for i in range(30):
    random_prompt = gpt3.sample(1)['prompt'].values[0]
    gpt35_sample = gpt35[gpt35['prompt'] == random_prompt]
    gpt3_sample = gpt3[gpt3['prompt'] == random_prompt]
    
    index_gpt3 = gpt3_sample.index[0]
    index_gpt35 = gpt35_sample.index[0]
    gpt3_text = gpt3_sample['text'].values[0]
    gpt35_text = gpt35_sample['text'].values[0]
    
    df = pd.concat([df, pd.DataFrame([[random_prompt, index_gpt3, gpt3_text, index_gpt35, gpt35_text]], columns=['prompt', 'index_gpt3', 'gpt3', 'index_gpt35', 'gpt35'])])

df.reset_index(drop=True)
# Out:
#                                                prompt index_gpt3  \
# 0            richard maxwell gaskin (born 8 may 1960)       1773
# 1              is a disaster novel by japanese writer       1230
# 2   antioch/oakley regional shoreline is a regiona...       2271
# 3                    acacia sibina is a tree or shrub         47
# 4   mini-mag orion (mmo), or miniature magnetic or...       1711
# 5                     wadsley is a suburb of the city       1023
# 6                  arthur reeves (1837 – 1915) was an        264
# 7               the trillium gap trail is an american       1793
# 8                     the coastal cup is a trophy and       2073
# 9   zhora "gevorg" saghateli harutyunyan (; septem...        489
# 10                    surya vs surya is a 2015 indian       1301
# 11            sisindiran is a sundanese poem in which        900
# 12         gordon dennis fox (born december 21, 1961)        582
# 13    ots 44 is a free-floating planetary-mass object        378
# 14              barry grogan (born 27 august 1986) is        168
# 15     in archery, a release aid, mechanical release,       1269
# 16              yadira narváez marín (born 1985) is a       1166
# 17   the chitral expedition (urdu:چترال فوجی مہم) was       1863
# 18                   wyoming highway 93 (wyo 93) is a        143
# 19          the lexington hotel was a ten-story hotel       1090
# 20       abrahm david devine (born september 3, 1996)       1105
# 21            "off kilter" is the first song released       1188
# 22              king william's war (also known as the        386
# 23           mariusz prudel (born 21 january 1986) is       1400
# 24              louis lerambert (1620 — 15 june 1670)       1516
# 25      carlos eduardo fernandes léo (born january 1,       1722
# 26         speakers of english are sometimes known as       1595
# 27                turpin high school is a public high        164
# 28           franklin battlefield was the site of the       1393
# 29             atal jaler ahwan is a bengali thriller        800
#
#                                                  gpt3 index_gpt35  \
# 0   richard maxwell gaskin (born 8 may 1960) is an...        2440
# 1   is a disaster novel by japanese writer sakyo k...        1525
# 2   antioch/oakley regional shoreline is a regiona...        1712
# 3   acacia sibina is a tree or shrub belonging to ...        1563
# 4   mini-mag orion (mmo), or miniature magnetic or...        2587
# 5   wadsley is a suburb of the city of sheffield, ...         115
# 6   arthur reeves (1837 – 1915) was an english foo...         940
# 7   the trillium gap trail is an american hiking t...        2436
# 8   the coastal cup is a trophy and soccer competi...        1706
# 9   zhora "gevorg" saghateli harutyunyan (; septem...         832
# 10  surya vs surya is a 2015 indian kannada-langua...          35
# 11  sisindiran is a sundanese poem in which an all...         387
# 12  gordon dennis fox (born december 21, 1961) is ...        1289
# 13  ots 44 is a free-floating planetary-mass objec...        1761
# 14  barry grogan (born 27 august 1986) is an irish...        1623
# 15  in archery, a release aid, mechanical release,...        1611
# 16  yadira narváez marín (born 1985) is a mexican ...        1779
# 17  the chitral expedition (urdu:چترال فوجی مہم) w...        1415
# 18  wyoming highway 93 (wyo 93) is a state highway...        2743
# 19  the lexington hotel was a ten-story hotel in c...         436
# 20  abrahm david devine (born september 3, 1996) i...          51
# 21  "off kilter" is the first song released from b...        2127
# 22  king william's war (also known as the second i...         636
# 23  mariusz prudel (born 21 january 1986) is a pol...         936
# 24  louis lerambert (1620 — 15 june 1670) was a fr...         697
# 25  carlos eduardo fernandes léo (born january 1, ...        1876
# 26  speakers of english are sometimes known as ang...        1794
# 27  turpin high school is a public high school in ...         975
# 28  franklin battlefield was the site of the final...         783
# 29  atal jaler ahwan is a bengali thriller drama f...        2779
#
#                                                 gpt35
# 0   richard maxwell gaskin (born 8 may 1960) is a ...
# 1   is a disaster novel by japanese writer sakyo k...
# 2   antioch/oakley regional shoreline is a regiona...
# 3   acacia sibina is a tree or shrub belonging to ...
# 4   mini-mag orion (mmo), or miniature magnetic or...
# 5   wadsley is a suburb of the city of sheffield i...
# 6   arthur reeves (1837 – 1915) was an english foo...
# 7   the trillium gap trail is an american hiking t...
# 8   the coastal cup is a trophy and soccer competi...
# 9   zhora "gevorg" saghateli harutyunyan (; septem...
# 10  surya vs surya is a 2015 indian telugu-languag...
# 11  sisindiran is a sundanese poem in which an all...
# 12  gordon dennis fox (born december 21, 1961) is ...
# 13  ots 44 is a free-floating planetary-mass objec...
# 14  barry grogan (born 27 august 1986) is an irish...
# 15  in archery, a release aid, mechanical release,...
# 16  yadira narváez marín (born 1985) is a colombia...
# 17  the chitral expedition (urdu:چترال فوجی مہم) w...
# 18  wyoming highway 93 (wyo 93) is a  north–south ...
# 19  the lexington hotel was a ten-story hotel loca...
# 20  abrahm david devine (born september 3, 1996) i...
# 21  "off kilter" is the first song released from b...
# 22  king william's war (also known as the second i...
# 23  mariusz prudel (born 21 january 1986) is a mal...
# 24  louis lerambert (1620 — 15 june 1670) was a fr...
# 25  carlos eduardo fernandes léo (born january 1, ...
# 26  speakers of english are sometimes known as ang...
# 27  turpin high school is a public high school in ...
# 28  franklin battlefield was the site of the secon...
# 29  atal jaler ahwan is a bengali thriller drama f...

# %%
# save to pickle
df.to_pickle('./dataset/deepdive.pickle')
